# %%
import os 
import json

# %%
# DATASET dict
# Obtained from https://cmsweb.cern.ch/das/

datasets = {
    # do we need preVBF samples?
    # no TT MTT sample for UL?
    "2016_UL": {
        "WJetsToLNu_HT-200To400_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "WJetsToLNu_HT-400To600_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "WJetsToLNu_HT-600To800_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "WJetsToLNu_HT-800To1200_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "WJetsToLNu_HT-1200To2500_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "WJetsToLNu_HT-2500ToInf_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "TTTo2L2Nu_TuneCP5_13TeV-powheg-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "TTToHadronic_TuneCP5_13TeV-powheg-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "ST_s-channel_4f_leptonDecays_TuneCP5_13TeV-amcatnlo-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "DYJetsToLL_Pt-50To100_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "DYJetsToLL_Pt-100To250_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "DYJetsToLL_Pt-250To400_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "DYJetsToLL_Pt-400To650_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "DYJetsToLL_Pt-650ToInf_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "WW_TuneCP5_13TeV-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "ZZ_TuneCP5_13TeV-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "WZ_TuneCP5_13TeV-pythia8": "RunIISummer20UL16NanoAODv2-106X_mcRun2_asymptotic_v15-v1/NANOAODSIM",
        "SingleMuon": [
            "Run2016B-ver1_HIPM_UL2016_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2016B-ver2_HIPM_UL2016_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2016C-UL2016_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2016D-UL2016_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2016D-UL2016_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2016E-UL2016_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2016F-UL2016_MiniAODv1_NanoAODv2-v1/NANOAOD",
        ],
        "SingleElectron": [
            "Run2016B-ver1_HIPM_UL2016_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2016B-ver2_HIPM_UL2016_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2016C-UL2016_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2016D-UL2016_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2016E-UL2016_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2016F-UL2016_MiniAODv1_NanoAODv2-v1/NANOAOD",
        ],
    },
    "2017_UL": {
        "WJetsToLNu_HT-200To400_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "WJetsToLNu_HT-400To600_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "WJetsToLNu_HT-600To800_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "WJetsToLNu_HT-800To1200_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "WJetsToLNu_HT-1200To2500_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "WJetsToLNu_HT-2500ToInf_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8" : "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "TTTo2L2Nu_TuneCP5_13TeV-powheg-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "TTToHadronic_TuneCP5_13TeV-powheg-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "ST_s-channel_4f_leptonDecays_TuneCP5_13TeV-amcatnlo-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "DYJetsToLL_Pt-50To100_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "DYJetsToLL_Pt-100To250_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "DYJetsToLL_Pt-250To400_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "DYJetsToLL_Pt-400To650_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "DYJetsToLL_Pt-650ToInf_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "WW_TuneCP5_13TeV-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "ZZ_TuneCP5_13TeV-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "WZ_TuneCP5_13TeV-pythia8": "RunIISummer20UL17NanoAODv2-106X_mc2017_realistic_v8-v1/NANOAODSIM",
        "SingleMuon": [
            "Run2017B-UL2017_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2017C-UL2017_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2017D-UL2017_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2017E-UL2017_MiniAODv1_NanoAODv2-v2/NANOAOD",
            "Run2017F-UL2017_MiniAODv1_NanoAODv2-v2/NANOAOD",
        ],
        "SingleElectron": [
            "Run2017B-UL2017_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2017C-UL2017_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2017D-UL2017_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2017E-UL2017_MiniAODv1_NanoAODv2-v2/NANOAOD",
            "Run2017F-UL2017_MiniAODv1_NanoAODv2-v1/NANOAOD",
        ],
    },
    "2018_UL": {
        "DYJetsToLL_Pt-50To100_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM",
        "DYJetsToLL_Pt-100To250_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM",
        "DYJetsToLL_Pt-250To400_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM",
        "DYJetsToLL_Pt-400To650_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM",
        "DYJetsToLL_Pt-650ToInf_MatchEWPDG20_TuneCP5_13TeV-amcatnloFXFX-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM",
        "WJetsToLNu_HT-70To100_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM/",
        "WJetsToLNu_HT-100To200_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM/",
        "WJetsToLNu_HT-200To400_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM/",
        "WJetsToLNu_HT-400To600_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM/",
        "WJetsToLNu_HT-600To800_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM/",
        "WJetsToLNu_HT-800To1200_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM/",
        "WJetsToLNu_HT-1200To2500_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM/",
        "WJetsToLNu_HT-2500ToInf_TuneCP5_13TeV-madgraphMLM-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM/",
        "ST_s-channel_4f_leptonDecays_TuneCP5_13TeV-amcatnlo-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM",
        "WW_TuneCP5_13TeV-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM",
        "WZ_TuneCP5_13TeV-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM",
        "ZZ_TuneCP5_13TeV-pythia8": "RunIISummer20UL18NanoAODv2-106X_upgrade2018_realistic_v15_L1v1-v1/NANOAODSIM",
        "SingleMuon": [
            "Run2018A-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018B-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018C-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018D-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018E-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018F-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018G-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018H-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018I-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018J-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018K-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018L-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018M-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018N-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018O-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018P-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018Q-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018R-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018S-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018T-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018U-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018V-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018X-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018Y-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
            "Run2018Z-UL2018_MiniAODv1_NanoAODv2-v3/NANOAOD",
        ],
        "EGamma": [
            "Run2018A-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018B-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018C-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018D-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018E-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018F-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018G-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018H-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018I-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018J-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018K-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018L-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018M-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018N-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018O-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018P-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018Q-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018R-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018S-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018T-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018U-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018V-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018X-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018Y-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
            "Run2018Z-UL2018_MiniAODv1_NanoAODv2-v1/NANOAOD",
        ]
    },
}

# %%
reco = "UL"
filesets = {}
years = ["2016","2017","2018"]
for year in years:
    yreco = f"{year}_{reco}"
    filesets[yreco] = {}
    for dataset,post in datasets[yreco].items():
        querys = []
        if isinstance(post, list):
            for x in post:
                querys.append(f"file dataset=/{dataset}/{x}")

        else:
            querys.append(f"file dataset=/{dataset}/{post}")
        filearray = []
        for newquery in querys:
            farray = !dasgoclient --query="file ${newquery}"
            filearray.extend(farray)
        filesets[yreco][dataset] = filearray

    with open(f"fileset_{yreco}_NANO.json", 'w') as json_file:
        json.dump(filesets[yreco], json_file, indent=4, sort_keys=True)
